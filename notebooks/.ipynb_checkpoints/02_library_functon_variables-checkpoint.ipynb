# %%
import math

# %%
math.sqrt(256)
# Out:
# 16.0

# %% [markdown]
# ### importing funcitons from library

# %%
from math import sqrt

# %%
sqrt(256)
# Out:
# 16.0

# %% [markdown]
# ### importing varaibles from library

# %%
from math import pi

# %%
pi
# Out:
# 3.141592653589793

# %% [markdown]
# #### using good naming conventions

# %%
pi * 4 * 4

# %%
radius = 4

# %%
area = pi * pow(radius,2) ## more readable then before

# %% [markdown]
# # we can see documentation of any module by help func

# %%
help(math)
# Out:
# Help on module math:
#
# NAME
#     math
#
# MODULE REFERENCE
#     https://docs.python.org/3.13/library/math.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#         The result is between 0 and pi.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
# ...

# %%
help(math.sqrt)
# Out:
# Help on built-in function sqrt in module math:
#
# sqrt(x, /)
#     Return the square root of x.

# %%
x = 24

# %%
x
# Out:
# 24

# %%
y = x * 2

# %%
y
# Out:
# 48

# %%
type(y)
# Out:
# int

# %%
y = 'a' * 2

# %%
y
# Out:
# 'aa'

# %%
type(y)
# Out:
# str

# %% [markdown]
# ### naming functions

# %%
f ### an error [NameError]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 f
#
# NameError: name 'f' is not defined

# %%
sqrt(56) ### just a funciton
# Out:
# 7.483314773547883

# %%
sqrt # interpretor tells us the type as function and it's location
# Out:
# <function math.sqrt(x, /)>

# %%
f(56)
# Out:
# 7.483314773547883

# %%
f = sqrt # changing the alias of function

# %%
f
# Out:
# <function math.sqrt(x, /)>

# %% [markdown]
# ### use pythontutur.com to see visualization of variables

# %% [markdown]
# ### side effects

# %%
print(f(25))
# Out:
# 5.0

# %%
"a"
# Out:
# 'a'

# %%
print("a")
# Out:
# a

# %%
print("the value of f(25) is:" , f(25)) #print automatically inset spaces between all values
# Out:
# the value of f(25) is:  5.0

# %%
s = """This is multi-line string
it can obv span multiple lines."""

# %%
s
# Out:
# 'This is multi-line string\nit can obv span multiple lines.'

# %%
print(s) ## can see the difference
# Out:
# This is multi-line string
# it can obv span multiple lines.
