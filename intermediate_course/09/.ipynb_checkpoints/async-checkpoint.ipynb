# %% [markdown]
# # Asynchronous Programming
# it's a growing trend!

# %%
# !pip install aiohttp
# Out:
# Requirement already satisfied: aiohttp in /home/zohaib/anaconda3/lib/python3.13/site-packages (3.11.10)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/zohaib/anaconda3/lib/python3.13/site-packages (from aiohttp) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/zohaib/anaconda3/lib/python3.13/site-packages (from aiohttp) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/zohaib/anaconda3/lib/python3.13/site-packages (from aiohttp) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/zohaib/anaconda3/lib/python3.13/site-packages (from aiohttp) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/zohaib/anaconda3/lib/python3.13/site-packages (from aiohttp) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/zohaib/anaconda3/lib/python3.13/site-packages (from aiohttp) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/zohaib/anaconda3/lib/python3.13/site-packages (from aiohttp) (1.18.0)
# Requirement already satisfied: idna>=2.0 in /home/zohaib/anaconda3/lib/python3.13/site-packages (from yarl<2.0,>=1.17.0->aiohttp) (3.7)

# %%
gists = ['https://gist.github.com/recluze/1d2989c7e345c8c3c542', 
        'https://gist.github.com/recluze/a98aa1804884ca3b3ad3', 
        'https://gist.github.com/recluze/5051735efe3fc189b90d', 
        'https://gist.github.com/recluze/460157afc6a7492555bb', 
        'https://gist.github.com/recluze/5051735efe3fc189b90d', 
        'https://gist.github.com/recluze/c9bc4130af995c36176d']

# %%
import asyncio
import aiohttp

# %%
async def get_gist(url):
    print(f"Get: {url}")

    async with aiohttp.ClientSession() as session:
        async with session.get(url) as response:
            page_text = await response.text()    # Out culprit
            g_length = len(page_text)
            print(f"Len: {g_length}")

# %%
async def get_gist(url):                           # Asynchronous 
    print('GET: ', url)
    
    async with aiohttp.ClientSession() as session: # Asynchronous 
        async with session.get(url) as response:   # Asynchronous 
            page_text = await response.text()      # Our culprit -- now we only have to define where we DO want to break 
            g_length = len(page_text)
            print("Len: %d" % g_length)
            return g_length                        # return value

# %%
# Set the async event loop
# Set the loop up 
asyncio.set_event_loop(asyncio.new_event_loop())   # An event loop runs async tasks 
loop = asyncio.get_event_loop()

# %%
# Add tasks to run
tasks = []
for g in gists:
    future = asyncio.ensure_future(  get_gist(g)  )
    tasks.append(future)   # save it for later refrence
# Out:
# GET:  https://gist.github.com/recluze/1d2989c7e345c8c3c542
# GET:  https://gist.github.com/recluze/a98aa1804884ca3b3ad3
# GET:  https://gist.github.com/recluze/5051735efe3fc189b90d
# GET:  https://gist.github.com/recluze/460157afc6a7492555bb
# GET:  https://gist.github.com/recluze/5051735efe3fc189b90d
# GET:  https://gist.github.com/recluze/c9bc4130af995c36176d
# Len: 139854
# Len: 180446
# Len: 109403
# Len: 112471
# Len: 109403
# Len: 314200

# %% [markdown]
# We're not running anything til now!

# %%
# Go! 
# %time loop.run_until_complete(asyncio.wait(tasks))

# %%
# Housekeeping 
loop.close()

# %%
tasks[0].result() # After the loop is done, we can get the return values
# Out:
# 314200

# %% [markdown]
# For my notebook it's running the future on the cell that they are created
